# %%
from glob import glob
import geopandas as gpd
from shapely.geometry import box
import sys
import os
sys.path.append(os.path.abspath(os.path.join('../')))
from scripts.visualizer import Visualizer

# %%
raster = rasterio.open("../iowa.tif")
bounds = raster.bounds

df = gpd.GeoDataFrame({"id":1,"geometry":[box(*bounds)]})

# save to file
df.to_file("iowa.shp")
print('Saved..')
# Out:
# Saved..

# %%
# shps = glob('sso_platte.shp')
gdf = gpd.GeoDataFrame.from_file('iowa.shp')

# %%
gdf
# Out:
#    id                                           geometry
# 0   1  POLYGON ((447611.391 4652575.193, 446112.391 4...

# %%
vis = Visualizer()
vis.visualize_raster()

# %%
# gdf['centroid_column'] = gdf.centroid

# gdf = gdf.set_geometry('centroid_column')
# gdf.plot();
